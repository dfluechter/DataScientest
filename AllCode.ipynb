# %%
# Data Exploration and HeatMaps

# %%
from google.colab import files
file = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from google.colab import files
#       2 file = files.upload()
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
import seaborn as sns
from matplotlib.cm import ScalarMappable
from matplotlib.colors import LinearSegmentedColormap, Normalize

#from google.colab import files
#file = files.upload()

#from google.colab import drive
#drive.flush_and_unmount()

#kamilas files1

import pandas as pd
df1 = pd.read_csv('./datasets/owid-co2-data.csv')[['country', 'iso_code','year','gdp',"population", "co2", "coal_co2", "gas_co2", "methane", "nitrous_oxide", "total_ghg", "oil_co2"]]
df2 = pd.read_csv('./datasets/hadcrut-surface-temperature-anomaly.csv')

merged_df = pd.merge(df1, df2, left_index=True, right_index=True)
merged_df = pd.concat([df1, df2], axis=0)

description = merged_df.describe()
print(description)
import matplotlib.pyplot as plt

description = merged_df.describe()

# Create a table
from tabulate import tabulate

description = merged_df.describe().transpose()

# Convert the statistical values to a table
table = tabulate(description, headers='keys', tablefmt='psql')

# Print the table
print(table)
# lib import
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

df1 = pd.read_csv('/content/owid-co2-data.csv')[['country', 'iso_code','year','gdp',"population", "co2", "coal_co2", "gas_co2", "methane", "nitrous_oxide", "total_ghg", "oil_co2"]]
df2 = pd.read_csv('/content/hadcrut-surface-temperature-anomaly.csv')

merged_df = pd.merge(df1, df2, left_index=True, right_index=True)
merged_df = pd.concat([df1, df2], axis=0)

# delete the nan values
clean_df = merged_df.dropna() #<-- You have too many NA so the shape the dataframe is equal to 0, clean_df is empty

# select the necessary inputs to focus on features can affect the global warming
light_df = clean_df

# use describe method to have basic stats values
light_df.describe()

#new
df=pd.read_csv('hadcrut-surface-temperature-anomaly.csv')
df=df.rename(columns={"Entity": "country", "Year" : "year"})

df_co2 = pd.read_csv('owid-co2-data.csv')

df_merge = df.merge(df_co2, on=['country', 'year'], how='left')

df_merge.corr().style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 import pandas as pd
#       3 import matplotlib.pyplot as plt
# ----> 4 import plotly.express as px
#       5 import numpy as np
#       6 import seaborn as sns
#
# ModuleNotFoundError: No module named 'plotly'

# %%
#reading the temperature anomaly data file
temp_anomal = pd.read_csv('./datasets/hadcrut-surface-temperature-anomaly.csv')
temp_anomal = temp_anomal.sort_values('Year') #we sort by years in the dataframe

#reading the CO2 data file
co2_data = pd.read_csv('./datasets/owid-co2-data.csv')

#displaying basic info about temp_anomal database
print(temp_anomal.info())
print("The shape of the temperature anomaly dataset is:", temp_anomal.shape)
#we see how manny missing values there are for each column
print(temp_anomal.isna().sum())
print("The dataset contains",temp_anomal.isna().sum().sum(), "NaN values, all for country ISO Code.")
#We calculate how many countries are listed in the dataset
print('The dataset contains information about', temp_anomal['Entity'].nunique(), 'countries.')
#We calculate how many data entries there are for each country
print('The data for each country is available for the following number of years:', temp_anomal['Entity'].value_counts())
#We see that the number of years with temperature anomaly data is not the same for each country
print('There is a distribution of entries for various countries. \
The values vary from information about 168 years of temperature anomalies to 64 years. However, the earlier data are available and are important in the project.')

#displaying basic info about co2_data database
print(co2_data.info())
print("The shape of the CO2 dataset is:", co2_data.shape)
#we see how manny missing values there are for each column
print(co2_data.isna().sum())
#We calculate how many countries are listed in the dataset, countries but also dependent states have ISO code
print('The dataset contains information about', co2_data['iso_code'].nunique(), 'countries and states.')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 29566 entries, 20165 to 29565
# Data columns (total 4 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Entity                       29566 non-null  object
#  1   Code                         29402 non-null  object
#  2   Year                         29566 non-null  int64
#  3   Surface temperature anomaly  29566 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.1+ MB
# None
# The shape of the temperature anomaly dataset is: (29566, 4)
# Entity                           0
# Code                           164
# Year                             0
# Surface temperature anomaly      0
# dtype: int64
# The dataset contains 164 NaN values, all for country ISO Code.
# The dataset contains information about 199 countries.
# The data for each country is available for the following number of years: Entity
# France                              168
# Netherlands                         168
# Argentina                           168
# Belarus                             168
# Romania                             168
# Slovenia                            168
# Luxembourg                          168
# Croatia                             168
# Estonia                             168
# Portugal                            168
# Andorra                             168
# Poland                              168
# Slovakia                            168
# Cuba                                168
# Ireland                             168
# Philippines                         168
# Denmark                             168
# Mauritius                           168
# Indonesia                           168
# Switzerland                         168
# South Africa                        168
# Belgium                             168
# Latvia                              168
# Moldova                             168
# Sweden                              168
# Vatican                             168
# Lesotho                             168
# Monaco                              168
# Azerbaijan                          168
# Sri Lanka                           168
# Ukraine                             168
# Australia                           168
# Hungary                             168
# Spain                               168
# China                               168
# Finland                             168
# Bosnia and Herzegovina              168
# Iceland                             168
# Lithuania                           168
# Bulgaria                            168
# Liechtenstein                       168
# San Marino                          168
# Cape Verde                          168
# Norway                              168
# Malaysia                            168
# United Kingdom                      168
# Czechia                             168
# Taiwan                              168
# Brazil                              168
# Italy                               168
# United States                       168
# Austria                             168
# Russia                              168
# Germany                             168
# Malta                               167
# Eswatini                            167
# East Timor                          167
# Tunisia                             167
# Palau                               167
# Brunei                              167
# Singapore                           167
# Dominican Republic                  167
# Albania                             166
# Bahamas                             166
# Western Sahara                      166
# Laos                                166
# Cambodia                            166
# Montenegro                          165
# Greece                              165
# Chile                               164
# Dominica                            164
# Antigua and Barbuda                 164
# Canada                              164
# Saint Kitts and Nevis               164
# Micronesia                          164
# Guinea                              164
# Haiti                               164
# Honduras                            163
# Barbados                            163
# Kiribati                            163
# Armenia                             163
# Costa Rica                          163
# Mexico                              163
# Gambia                              163
# Guinea-Bissau                       163
# Georgia                             163
# Gabon                               162
# Uruguay                             162
# Liberia                             162
# Nicaragua                           162
# Equatorial Guinea                   162
# Sierra Leone                        161
# Guatemala                           161
# Fiji                                161
# Saint Lucia                         160
# Jamaica                             160
# Trinidad and Tobago                 160
# Suriname                            160
# Saint Vincent and the Grenadines    160
# Grenada                             160
# Tonga                               159
# India                               159
# El Salvador                         159
# Solomon Islands                     158
# Samoa                               158
# Maldives                            157
# Seychelles                          157
# Panama                              157
# Morocco                             156
# North Korea                         156
# Sao Tome and Principe               156
# Libya                               155
# Vanuatu                             155
# Comoros                             155
# Myanmar                             154
# Turkey                              153
# New Zealand                         153
# Bangladesh                          153
# Japan                               152
# Colombia                            151
# Israel                              151
# Madagascar                          151
# Mozambique                          151
# Cyprus                              150
# Djibouti                            150
# Eritrea                             150
# Malawi                              150
# Saudi Arabia                        149
# Namibia                             148
# Bhutan                              148
# Tanzania                            148
# Egypt                               148
# Sudan                               148
# Jordan                              147
# Syria                               147
# Lebanon                             147
# Thailand                            147
# Nepal                               147
# Marshall Islands                    146
# Qatar                               144
# Bahrain                             144
# Nauru                               144
# Pakistan                            143
# Papua New Guinea                    141
# Iran                                141
# Algeria                             140
# Peru                                140
# South Korea                         139
# Togo                                139
# Benin                               139
# Congo                               138
# Kyrgyzstan                          137
# Kazakhstan                          137
# Cote d'Ivoire                       137
# Belize                              134
# Mongolia                            134
# Somalia                             133
# Kosovo                              133
# North Macedonia                     133
# Serbia                              133
# Ghana                               132
# Kenya                               132
# Northern Cyprus                     130
# Yemen                               129
# United Arab Emirates                128
# Oman                                128
# Bolivia                             127
# Tuvalu                              127
# Turkmenistan                        126
# Uzbekistan                          126
# Ecuador                             126
# Botswana                            120
# Zimbabwe                            120
# Nigeria                             120
# Kuwait                              119
# Cameroon                            117
# Senegal                             116
# Venezuela                           113
# Uganda                              111
# Burundi                             111
# Rwanda                              111
# Mali                                108
# Iraq                                108
# Niger                               104
# Tajikistan                           99
# Angola                               97
# Zambia                               95
# Burkina Faso                         93
# Ethiopia                             92
# Antarctica                           91
# Mauritania                           90
# Democratic Republic of Congo         78
# Central African Republic             77
# Paraguay                             77
# Vietnam                              72
# South Sudan                          72
# Afghanistan                          71
# Guyana                               70
# Chad                                 64
# Name: count, dtype: int64
# There is a distribution of entries for various countries. The values vary from information about 168 years of temperature anomalies to 64 years. However, the earlier data are available and are important in the project.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50598 entries, 0 to 50597
# Data columns (total 79 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   country                                    50598 non-null  object
#  1   year                                       50598 non-null  int64
#  2   iso_code                                   41970 non-null  object
#  3   population                                 40008 non-null  float64
#  4   gdp                                        14564 non-null  float64
#  5   cement_co2                                 24974 non-null  float64
#  6   cement_co2_per_capita                      22714 non-null  float64
#  7   co2                                        31349 non-null  float64
#  8   co2_growth_abs                             28944 non-null  float64
#  9   co2_growth_prct                            25032 non-null  float64
#  10  co2_including_luc                          24212 non-null  float64
#  11  co2_including_luc_growth_abs               23909 non-null  float64
#  12  co2_including_luc_growth_prct              24129 non-null  float64
#  13  co2_including_luc_per_capita               23690 non-null  float64
#  14  co2_including_luc_per_gdp                  15701 non-null  float64
#  15  co2_including_luc_per_unit_energy          9528 non-null   float64
#  16  co2_per_capita                             26915 non-null  float64
#  17  co2_per_gdp                                16291 non-null  float64
#  18  co2_per_unit_energy                        10054 non-null  float64
#  19  coal_co2                                   25069 non-null  float64
#  20  coal_co2_per_capita                        24421 non-null  float64
#  21  consumption_co2                            4600 non-null   float64
#  22  consumption_co2_per_capita                 4227 non-null   float64
#  23  consumption_co2_per_gdp                    3898 non-null   float64
#  24  cumulative_cement_co2                      24873 non-null  float64
#  25  cumulative_co2                             29356 non-null  float64
#  26  cumulative_co2_including_luc               24212 non-null  float64
#  27  cumulative_coal_co2                        24968 non-null  float64
#  28  cumulative_flaring_co2                     24774 non-null  float64
#  29  cumulative_gas_co2                         24842 non-null  float64
#  30  cumulative_luc_co2                         39388 non-null  float64
#  31  cumulative_oil_co2                         24941 non-null  float64
#  32  cumulative_other_co2                       2386 non-null   float64
#  33  energy_per_capita                          10048 non-null  float64
#  34  energy_per_gdp                             7159 non-null   float64
#  35  flaring_co2                                24875 non-null  float64
#  36  flaring_co2_per_capita                     24272 non-null  float64
#  37  gas_co2                                    24943 non-null  float64
#  38  gas_co2_per_capita                         24340 non-null  float64
#  39  ghg_excluding_lucf_per_capita              6149 non-null   float64
#  40  ghg_per_capita                             6149 non-null   float64
#  41  land_use_change_co2                        39388 non-null  float64
#  42  land_use_change_co2_per_capita             36026 non-null  float64
#  43  methane                                    6150 non-null   float64
#  44  methane_per_capita                         6150 non-null   float64
#  45  nitrous_oxide                              6150 non-null   float64
#  46  nitrous_oxide_per_capita                   6150 non-null   float64
#  47  oil_co2                                    25042 non-null  float64
#  48  oil_co2_per_capita                         24367 non-null  float64
#  49  other_co2_per_capita                       2386 non-null   float64
#  50  other_industry_co2                         2386 non-null   float64
#  51  primary_energy_consumption                 10115 non-null  float64
#  52  share_global_cement_co2                    20830 non-null  float64
#  53  share_global_co2                           29356 non-null  float64
#  54  share_global_co2_including_luc             24212 non-null  float64
#  55  share_global_coal_co2                      24968 non-null  float64
#  56  share_global_cumulative_cement_co2         20830 non-null  float64
#  57  share_global_cumulative_co2                29356 non-null  float64
#  58  share_global_cumulative_co2_including_luc  24212 non-null  float64
#  59  share_global_cumulative_coal_co2           24968 non-null  float64
#  60  share_global_cumulative_flaring_co2        15980 non-null  float64
#  61  share_global_cumulative_gas_co2            21990 non-null  float64
#  62  share_global_cumulative_luc_co2            39388 non-null  float64
#  63  share_global_cumulative_oil_co2            23421 non-null  float64
#  64  share_global_cumulative_other_co2          2386 non-null   float64
#  65  share_global_flaring_co2                   15980 non-null  float64
#  66  share_global_gas_co2                       21990 non-null  float64
#  67  share_global_luc_co2                       39388 non-null  float64
#  68  share_global_oil_co2                       23421 non-null  float64
#  69  share_global_other_co2                     2386 non-null   float64
#  70  share_of_temperature_change_from_ghg       41724 non-null  float64
#  71  temperature_change_from_ch4                37620 non-null  float64
#  72  temperature_change_from_co2                41724 non-null  float64
#  73  temperature_change_from_ghg                41724 non-null  float64
#  74  temperature_change_from_n2o                37620 non-null  float64
#  75  total_ghg                                  6149 non-null   float64
#  76  total_ghg_excluding_lucf                   6149 non-null   float64
#  77  trade_co2                                  4259 non-null   float64
#  78  trade_co2_share                            4258 non-null   float64
# dtypes: float64(76), int64(1), object(2)
# memory usage: 30.5+ MB
# None
# The shape of the CO2 dataset is: (50598, 79)
# country                                          0
# year                                             0
# iso_code                                      8628
# population                                   10590
# gdp                                          36034
# cement_co2                                   25624
# cement_co2_per_capita                        27884
# co2                                          19249
# co2_growth_abs                               21654
# co2_growth_prct                              25566
# co2_including_luc                            26386
# co2_including_luc_growth_abs                 26689
# co2_including_luc_growth_prct                26469
# co2_including_luc_per_capita                 26908
# co2_including_luc_per_gdp                    34897
# co2_including_luc_per_unit_energy            41070
# co2_per_capita                               23683
# co2_per_gdp                                  34307
# co2_per_unit_energy                          40544
# coal_co2                                     25529
# coal_co2_per_capita                          26177
# consumption_co2                              45998
# consumption_co2_per_capita                   46371
# consumption_co2_per_gdp                      46700
# cumulative_cement_co2                        25725
# cumulative_co2                               21242
# cumulative_co2_including_luc                 26386
# cumulative_coal_co2                          25630
# cumulative_flaring_co2                       25824
# cumulative_gas_co2                           25756
# cumulative_luc_co2                           11210
# cumulative_oil_co2                           25657
# cumulative_other_co2                         48212
# energy_per_capita                            40550
# energy_per_gdp                               43439
# flaring_co2                                  25723
# flaring_co2_per_capita                       26326
# gas_co2                                      25655
# gas_co2_per_capita                           26258
# ghg_excluding_lucf_per_capita                44449
# ghg_per_capita                               44449
# land_use_change_co2                          11210
# land_use_change_co2_per_capita               14572
# methane                                      44448
# methane_per_capita                           44448
# nitrous_oxide                                44448
# nitrous_oxide_per_capita                     44448
# oil_co2                                      25556
# oil_co2_per_capita                           26231
# other_co2_per_capita                         48212
# other_industry_co2                           48212
# primary_energy_consumption                   40483
# share_global_cement_co2                      29768
# share_global_co2                             21242
# share_global_co2_including_luc               26386
# share_global_coal_co2                        25630
# share_global_cumulative_cement_co2           29768
# share_global_cumulative_co2                  21242
# share_global_cumulative_co2_including_luc    26386
# share_global_cumulative_coal_co2             25630
# share_global_cumulative_flaring_co2          34618
# share_global_cumulative_gas_co2              28608
# share_global_cumulative_luc_co2              11210
# share_global_cumulative_oil_co2              27177
# share_global_cumulative_other_co2            48212
# share_global_flaring_co2                     34618
# share_global_gas_co2                         28608
# share_global_luc_co2                         11210
# share_global_oil_co2                         27177
# share_global_other_co2                       48212
# share_of_temperature_change_from_ghg          8874
# temperature_change_from_ch4                  12978
# temperature_change_from_co2                   8874
# temperature_change_from_ghg                   8874
# temperature_change_from_n2o                  12978
# total_ghg                                    44449
# total_ghg_excluding_lucf                     44449
# trade_co2                                    46339
# trade_co2_share                              46340
# dtype: int64
# The dataset contains information about 231 countries and states.

# %%
#function for plotting 5 countries with the highest temperature anomalies
def countries_temp_anomaly(year):
    #we choose one specific year for the data, eg. 2017
    year_data = temp_anomal[temp_anomal['Year'] == year]
    used_data = year_data[['Entity', 'Surface temperature anomaly']]
    sorted_data = used_data.sort_values('Surface temperature anomaly', ascending=False).reset_index(drop=True)
    chart_data = sorted_data.iloc[:5]

    print(chart_data)
    # create bar chart
    plt.bar(chart_data['Entity'], chart_data['Surface temperature anomaly'],
            color=['#f6d2a9','#f5b78e','#f19c7c','#ea8171','#dd686c'])
    plt.title('Countries with the highest temperature anomaly in deg C (2017)')
    plt.xticks(fontsize=8)
    plt.show()

#function for plotting 5 countries with the highest CO2 emissions
def co2_emissions(year):
    year_data = co2_data[co2_data['year'] == year]
    # we use isna to remove the separate the countries and aggregated records for areas (eg. Asia)
    # only countries and dependent states have iso code
    country_data = year_data[pd.notna(year_data['iso_code'])]
    used_data = country_data[['country', 'co2']]
    sorted_data = used_data.sort_values('co2', ascending=False).reset_index(drop=True)
    chart_data = sorted_data.iloc[:5]
    print(chart_data)
    # create bar chart
    plt.bar(chart_data['country'], chart_data['co2'],
            color=["#115f9a", "#1984c5", "#22a7f0", "#48b5c4", "#76c68f"])
    plt.title('Countries with the highest CO2 emissions in million tons (2021)')
    plt.xticks(fontsize=8)
    plt.show()


#function for plotting 7 countries with the highest share to the world CO2 emissions
def countries_share_piechart(year):
    year_data = co2_data[co2_data['year'] == year]
    # we use isna to remove the separate the countries and aggregated records for areas (eg. Asia)
    # only countries have iso code
    country_data = year_data[pd.notna(year_data['iso_code'])]
    used_data = country_data[['country', 'share_global_co2']]
    sorted_data = used_data.sort_values('share_global_co2', ascending=False).reset_index(drop=True)
    chart_data = sorted_data.iloc[:7]
    other_share = sorted_data.loc[7:, 'share_global_co2'].sum()
    chart_data.loc[7] = ("Other", other_share)
    plt.title('Global share to the $\mathdefault{CO_2}$ emissions', pad=32)
    print(chart_data)


    colors = sns.color_palette("Paired")
    #labels = chart_data[chart_data['country']]
    # create pie chart
    plt.pie(chart_data['share_global_co2'], labels= chart_data['country'], colors=colors, autopct='%.0f%%',
        explode = [0.1, 0, 0, 0, 0, 0, 0, 0],
        pctdistance = 0.9, labeldistance = 1.2, radius=1.3)

    plt.show()


#function for plotting 5 countries with the highest CO2 emissions
def country_co2_emission(country):
    country_data = co2_data[co2_data['country'] == country]
    x = country_data['year']
    y1 = country_data['population']
    y2 = country_data['co2']
    y3 = country_data['co2_per_capita']

    fig, ax = plt.subplots()
    fig.subplots_adjust(right=0.75)

    twin1 = ax.twinx()
    twin2 = ax.twinx()

    # Offset the right spine of twin2.  The ticks and label have already been
    # placed on the right by twinx above.
    twin2.spines.right.set_position(("axes", 1.2))

    p1, = ax.plot(x, y1, "b-", label = "Population")
    p2, = twin1.plot(x, y2, "r-", label="$\mathdefault{CO_2}$")
    p3, = twin2.plot(x, y3, "g-", label="$\mathdefault{CO_2}$ per capita")


    ax.set_xlabel("Year")
    ax.set_ylabel("Population")
    twin1.set_ylabel("$\mathdefault{CO_2}$ [million tonnes]")
    twin2.set_ylabel("$\mathdefault{CO_2}$ per capita [tons pp]")

    ax.yaxis.label.set_color(p1.get_color())
    twin1.yaxis.label.set_color(p2.get_color())
    twin2.yaxis.label.set_color(p3.get_color())

    tkw = dict(size=4, width=1.5)
    ax.tick_params(axis='y', colors=p1.get_color(), **tkw)
    twin1.tick_params(axis='y', colors=p2.get_color(), **tkw)
    twin2.tick_params(axis='y', colors=p3.get_color(), **tkw)
    ax.tick_params(axis='x', **tkw)

    ax.legend(handles=[p1, p2, p3])
    plt.title(country +' $\mathdefault{CO_2}$ emissions')
    plt.show()

#function for plotting what is the countries share in the temperature change
def share_temp(year):
    year_data = co2_data[co2_data['year'] == year]
    # we use isna to remove the separate the countries and aggregated records for areas (eg. Asia)
    # only countries and dependent states have iso code
    country_data = year_data[pd.notna(year_data['iso_code'])]
    used_data = country_data[['country', 'share_of_temperature_change_from_ghg']]
    sorted_data = used_data.sort_values('share_of_temperature_change_from_ghg', ascending=False).reset_index(drop=True)
    chart_data = sorted_data.iloc[:7]
    other_share = sorted_data.loc[7:, 'share_of_temperature_change_from_ghg'].sum()
    chart_data.loc[7] = ("Other", other_share)
    print(chart_data)
    # create bar chart
    plt.bar(chart_data['country'], chart_data['share_of_temperature_change_from_ghg'],
            color=['#1D5B79', '#468B97', '#EF6262', '#F3AA60', '#1A5D1A', '#A84448', '#539165', '#3F497F'])
    plt.title('Share of contribution to global warming [in %]')
    plt.xticks(fontsize=8)
    plt.show()


#function for plotting the animated map for countries temperature anomalies
def animated_temp_map():
    fig = px.choropleth(temp_anomal, locations="Code",
                        color="Surface temperature anomaly", # temp anomally per country
                        hover_name="Entity", # column to add to hover information
                        animation_frame='Year',
                        range_color=(-3, max(temp_anomal['Surface temperature anomaly'])),
                        color_continuous_scale=px.colors.sequential.Plasma)

    fig.update_coloraxes(colorbar_ticksuffix ='  deg C') #we add suffix to the temp anomaly in the colorbar
    fig.update_layout(
        title_text='Surface temperature anomaly',
        geo=dict(
            showframe=False,
            showcoastlines=False,
            projection_type='equirectangular'
        ),
        annotations = [dict(
            x=0.55,
            y=0.2,
            xref='paper',
            yref='paper',
            text='Source: <a href="https://ourworldindata.org/grapher/hadcrut-surface-temperature-anomaly">\
                Our World In Data</a>',
            showarrow = False
        )]
    )

    fig.show()


#function for plotting the map for countries temperature anomalies for a specific year
def yearly_temp_map(year):
    fig = px.choropleth(temp_anomal[temp_anomal['Year']==year], locations="Code", #we plot data for the year (eg. 2017)
                        color="Surface temperature anomaly", # temp anomaly per country
                        hover_name="Entity", # column to add to hover information
                        color_continuous_scale=px.colors.sequential.Plasma #colorbar style
                        )

    fig.update_coloraxes(colorbar_ticksuffix ='  deg C') #we add suffix to the temp anomaly in the colorbar
    fig.update_layout(
        title_text='Surface temperature anomaly, 2017',
        geo=dict(
            showframe=False,
            showcoastlines=False,
            projection_type='equirectangular'
        ),
        annotations = [dict(
            x=0.55,
            y=0.2,
            xref='paper',
            yref='paper',
            text='Source: <a href="https://ourworldindata.org/grapher/hadcrut-surface-temperature-anomaly">\
                Our World In Data</a>',
            showarrow = False
        )]
    )
    fig.show()

#calling the plot functions
animated_temp_map()
yearly_temp_map(2017)
countries_temp_anomaly(2017)
co2_emissions(2021)
countries_share_piechart(2021)
country_co2_emission('China')
country_co2_emission('Europe')
share_temp(2021)

print("The countries affected the most by the temperature anomalies are Mongolia, Somalia, Norway, Russia and Afghanistan.")
print("However, these are not the countries that have the highest CO2 emissions")
print("The countries with the highest emissions are China, US, India, Russia and Japan")
print("In China, the emissions are increasing constantly, while in Europe there is a decreasing trend from around 1980.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 182
#     179     fig.show()
#     181 #calling the plot functions
# --> 182 animated_temp_map()
#     183 yearly_temp_map(2017)
#     184 countries_temp_anomaly(2017)
#
# Cell In[2], line 124, in animated_temp_map()
#     123 def animated_temp_map():
# --> 124     fig = px.choropleth(temp_anomal, locations="Code",
#     125                         color="Surface temperature anomaly", # temp anomally per country
#     126                         hover_name="Entity", # column to add to hover information
#     127                         animation_frame='Year',
#     128                         range_color=(-3, max(temp_anomal['Surface temperature anomaly'])),
#     129                         color_continuous_scale=px.colors.sequential.Plasma)
#     131     fig.update_coloraxes(colorbar_ticksuffix ='  deg C') #we add suffix to the temp anomaly in the colorbar
#     132     fig.update_layout(
#     133         title_text='Surface temperature anomaly',
#     134         geo=dict(
#    (...)
#     147         )]
#     148     )
#
# NameError: name 'px' is not defined

# %%
# lib import
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#from tabulate import tabulate
# %matplotlib inline
pd.set_option('display.max_rows', None)

# %%
#load the data
df1 = pd.read_csv('./datasets/owid-co2-data.csv')
df2 = pd.read_csv('./datasets/hadcrut-surface-temperature-anomaly.csv')

# %%
#merge the datas
df2=df2.rename(columns={"Entity": "country", "Year" : "year"})
merged_df = df1.merge(df2, on=['country', 'year'], how='left')

# %%
#count nan values
pd.DataFrame((merged_df.isnull().sum() * 100 / len(merged_df)).round(3)).style.background_gradient(cmap='coolwarm').set_precision(3)
import pandas as pd
import matplotlib.pyplot as plt

# Calculate the percentage of missing values in each column
missing_percentage = (merged_df.isnull().sum() * 100 / len(merged_df)).round(3)

# Create a DataFrame with the missing percentages
missing_table = pd.DataFrame(missing_percentage, columns=['Missing Percentage'])

# Apply background color gradient
table_style = missing_table.style.background_gradient(cmap='coolwarm')

# Set precision for the displayed percentages
table_style.set_precision(3)

# Display the table with color-coded missing percentage
plt.figure(figsize=(8, 6))
plt.axis('off')
plt.table(cellText=missing_table.values,
          colLabels=missing_table.columns,
          cellLoc='center',
          rowLabels=missing_table.index,
          loc='center',
          cellColours=plt.cm.coolwarm(missing_table / 100),
          colColours=plt.cm.coolwarm(missing_table / 100))


# Save the table as an image
plt.savefig('missing_data_table.png', bbox_inches='tight')

# Display the table on the screen
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 2
#       1 #count nan values
# ----> 2 pd.DataFrame((merged_df.isnull().sum() * 100 / len(merged_df)).round(3)).style.background_gradient(cmap='coolwarm').set_precision(3)
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#
# AttributeError: 'Styler' object has no attribute 'set_precision'

# %%
#info of datas
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50598 entries, 0 to 50597
# Data columns (total 81 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   country                                    50598 non-null  object
#  1   year                                       50598 non-null  int64
#  2   iso_code                                   41970 non-null  object
#  3   population                                 40008 non-null  float64
#  4   gdp                                        14564 non-null  float64
#  5   cement_co2                                 24974 non-null  float64
#  6   cement_co2_per_capita                      22714 non-null  float64
#  7   co2                                        31349 non-null  float64
#  8   co2_growth_abs                             28944 non-null  float64
#  9   co2_growth_prct                            25032 non-null  float64
#  10  co2_including_luc                          24212 non-null  float64
#  11  co2_including_luc_growth_abs               23909 non-null  float64
#  12  co2_including_luc_growth_prct              24129 non-null  float64
#  13  co2_including_luc_per_capita               23690 non-null  float64
#  14  co2_including_luc_per_gdp                  15701 non-null  float64
#  15  co2_including_luc_per_unit_energy          9528 non-null   float64
#  16  co2_per_capita                             26915 non-null  float64
#  17  co2_per_gdp                                16291 non-null  float64
#  18  co2_per_unit_energy                        10054 non-null  float64
#  19  coal_co2                                   25069 non-null  float64
#  20  coal_co2_per_capita                        24421 non-null  float64
#  21  consumption_co2                            4600 non-null   float64
#  22  consumption_co2_per_capita                 4227 non-null   float64
#  23  consumption_co2_per_gdp                    3898 non-null   float64
#  24  cumulative_cement_co2                      24873 non-null  float64
#  25  cumulative_co2                             29356 non-null  float64
#  26  cumulative_co2_including_luc               24212 non-null  float64
#  27  cumulative_coal_co2                        24968 non-null  float64
#  28  cumulative_flaring_co2                     24774 non-null  float64
#  29  cumulative_gas_co2                         24842 non-null  float64
#  30  cumulative_luc_co2                         39388 non-null  float64
#  31  cumulative_oil_co2                         24941 non-null  float64
#  32  cumulative_other_co2                       2386 non-null   float64
#  33  energy_per_capita                          10048 non-null  float64
#  34  energy_per_gdp                             7159 non-null   float64
#  35  flaring_co2                                24875 non-null  float64
#  36  flaring_co2_per_capita                     24272 non-null  float64
#  37  gas_co2                                    24943 non-null  float64
#  38  gas_co2_per_capita                         24340 non-null  float64
#  39  ghg_excluding_lucf_per_capita              6149 non-null   float64
#  40  ghg_per_capita                             6149 non-null   float64
#  41  land_use_change_co2                        39388 non-null  float64
#  42  land_use_change_co2_per_capita             36026 non-null  float64
#  43  methane                                    6150 non-null   float64
#  44  methane_per_capita                         6150 non-null   float64
#  45  nitrous_oxide                              6150 non-null   float64
#  46  nitrous_oxide_per_capita                   6150 non-null   float64
#  47  oil_co2                                    25042 non-null  float64
#  48  oil_co2_per_capita                         24367 non-null  float64
#  49  other_co2_per_capita                       2386 non-null   float64
#  50  other_industry_co2                         2386 non-null   float64
#  51  primary_energy_consumption                 10115 non-null  float64
#  52  share_global_cement_co2                    20830 non-null  float64
#  53  share_global_co2                           29356 non-null  float64
#  54  share_global_co2_including_luc             24212 non-null  float64
#  55  share_global_coal_co2                      24968 non-null  float64
#  56  share_global_cumulative_cement_co2         20830 non-null  float64
#  57  share_global_cumulative_co2                29356 non-null  float64
#  58  share_global_cumulative_co2_including_luc  24212 non-null  float64
#  59  share_global_cumulative_coal_co2           24968 non-null  float64
#  60  share_global_cumulative_flaring_co2        15980 non-null  float64
#  61  share_global_cumulative_gas_co2            21990 non-null  float64
#  62  share_global_cumulative_luc_co2            39388 non-null  float64
#  63  share_global_cumulative_oil_co2            23421 non-null  float64
#  64  share_global_cumulative_other_co2          2386 non-null   float64
#  65  share_global_flaring_co2                   15980 non-null  float64
#  66  share_global_gas_co2                       21990 non-null  float64
#  67  share_global_luc_co2                       39388 non-null  float64
#  68  share_global_oil_co2                       23421 non-null  float64
#  69  share_global_other_co2                     2386 non-null   float64
#  70  share_of_temperature_change_from_ghg       41724 non-null  float64
#  71  temperature_change_from_ch4                37620 non-null  float64
#  72  temperature_change_from_co2                41724 non-null  float64
#  73  temperature_change_from_ghg                41724 non-null  float64
#  74  temperature_change_from_n2o                37620 non-null  float64
#  75  total_ghg                                  6149 non-null   float64
#  76  total_ghg_excluding_lucf                   6149 non-null   float64
#  77  trade_co2                                  4259 non-null   float64
#  78  trade_co2_share                            4258 non-null   float64
#  79  Code                                       28598 non-null  object
#  80  Surface temperature anomaly                28598 non-null  float64
# dtypes: float64(77), int64(1), object(3)
# memory usage: 31.3+ MB

# %%
#stats of data
merged_df.describe().style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[52], line 2
#       1 #stats of data
# ----> 2 merged_df.describe().style.background_gradient(cmap='coolwarm').set_precision(3)
#
# AttributeError: 'Styler' object has no attribute 'set_precision'

# %%
select_cols = ['year','gdp',"population", "co2", "coal_co2", "gas_co2", "methane", "nitrous_oxide", "total_ghg", "oil_co2", 'Surface temperature anomaly']
merged_df[select_cols].describe().style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 2
#       1 select_cols = ['year','gdp',"population", "co2", "coal_co2", "gas_co2", "methane", "nitrous_oxide", "total_ghg", "oil_co2", 'Surface temperature anomaly']
# ----> 2 merged_df[select_cols].describe().style.background_gradient(cmap='coolwarm').set_precision(3)
#
# AttributeError: 'Styler' object has no attribute 'set_precision'

# %%
#CORRELATION
merged_df.corr().style.background_gradient(cmap='coolwarm').set_precision(3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 2
#       1 #CORRELATION
# ----> 2 merged_df.corr().style.background_gradient(cmap='coolwarm').set_precision(3)
#
# File c:\Users\Domski\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Domski\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\Domski\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\Users\Domski\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Afghanistan'

# %%
#heatMapCleanedData
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./datasets/datas_pre_processed.csv')
df.reset_index(drop=True, inplace=True)
correlation_matrix = df.corr()
correlation_matrix
plt.figure(figsize=(16, 14))


sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

plt.title('Correlation Heatmap')
plt.show()

#Conclusion: surface temperature anomaly seems to have the strongest correlation with year variable. Intensity of the color indicates the low dependence With other variables. However with variables like flaring_co2, gas_co2, gdp, population,coal_co2, co2 correlation is stronger than with land_use_change_co2, trade_co2, oil_co2.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 6
#       3 import pandas as pd
#       4 import matplotlib.pyplot as plt
# ----> 6 df = pd.read_csv('./datasets/datas_pre_processed.csv')
#       7 df.reset_index(drop=True, inplace=True)
#       8 correlation_matrix = df.corr()
#
# File c:\Users\Domski\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Domski\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File c:\Users\Domski\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Domski\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File c:\Users\Domski\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './datasets/datas_pre_processed.csv'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('/content/datas_pre_processed.csv')



# Pivot the DataFrame to have 'year' as index, 'country' as columns, and 'surface temperature anomaly' as values
heatmap_data = df.pivot(index='year', columns='country', values='surface temperature anomaly')

# Create the heatmap using seaborn
plt.figure(figsize=(20, 22))
sns.heatmap(heatmap_data, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Surface Temperature Anomaly Heatmap')
plt.xlabel('Country')
plt.ylabel('Year')
plt.show()

# %%
#Basic statistics Values
import matplotlib
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('/content/owid-co2-data.csv')
print(df.head())



# Calculate Mean
mean_population = df['population'].mean()
mean_gdp = df['gdp'].mean()
mean_co2_emissions = df['co2'].mean()

# Calculate Median
median_co2_per_capita = df['co2_per_capita'].median()
median_temperature_change_from_co2 = df['temperature_change_from_co2'].median()



# Calculate Range
range_co2_emissions = df['co2'].max() - df['co2'].min()
range_gdp = df['gdp'].max() - df['gdp'].min()

# Calculate Variance and Standard Deviation
variance_co2_per_capita = df['co2_per_capita'].var()
std_dev_co2_emissions = df['co2'].std()

# Calculate Percentiles
percentile_25_co2_emissions = df['co2'].quantile(0.25)
percentile_75_gdp = df['gdp'].quantile(0.75)

# Calculate Correlation
correlation_co2_gdp = df['co2'].corr(df['gdp'])

# Display the results
print("Mean Population:", mean_population)
print("Mean GDP:", mean_gdp)
print("Mean CO2 Emissions:", mean_co2_emissions)
print("Median CO2 Emissions per Capita:", median_co2_per_capita)
print("Median Temperature Change from CO2:", median_temperature_change_from_co2)
print("Range of CO2 Emissions:", range_co2_emissions)
print("Range of GDP:", range_gdp)
print("Variance of CO2 Emissions per Capita:", variance_co2_per_capita)
print("Standard Deviation of CO2 Emissions:", std_dev_co2_emissions)
print("25th Percentile of CO2 Emissions:", percentile_25_co2_emissions)
print("75th Percentile of GDP:", percentile_75_gdp)
print("Correlation between CO2 Emissions and GDP:", correlation_co2_gdp)

# %%
#Modelistation
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
#!pip install shap

# Dataset import
data = pd.read_csv('/content/datas_pre_processed.csv')

#drop NaN values
data.dropna(inplace=True)
print(data.isna().sum().sum())

# Separate the features (X) and target (y)
X = data[['country', 'code', 'year', 'cement_co2', 'co2', 'coal_co2', 'consumption_co2',
          'cumulative_co2', 'flaring_co2', 'gas_co2', 'land_use_change_co2', 'oil_co2',
          'trade_co2', 'temperature_change_from_ghg', 'total_ghg', 'gdp', 'population']]
y = data['surface temperature anomaly']

# Perform one-hot encoding using pandas get_dummies
X_encoded = pd.get_dummies(X, columns=['country', 'code'], drop_first=True)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)
# Out:
# 0

# %%
# Model 1: Gradient Boosting
gb_model = GradientBoostingRegressor()
gb_model.fit(X_train, y_train)
gb_predictions = gb_model.predict(X_test)

plt.scatter(y_test, gb_predictions)
plt.xlabel("Actual Surface Temperature Anomaly")
plt.ylabel("Predicted Surface Temperature Anomaly")
plt.title("Gradient Boosting: Actual vs. Predicted")
plt.show()

#residual plot shows the difference between the actual target values and the predicted values
residuals = y_test - gb_predictions
plt.hist(residuals, bins=30)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Gradient Boosting: Histogram of Residuals")
plt.show()

# Sort feature importances in descending order
plt.figure(figsize=(18, 6))
plt.bar(range(len(feature_importances)), feature_importances)
plt.xticks(range(len(feature_importances)), feature_names, rotation=45, ha='right')
plt.xlabel("Features")
plt.ylabel("Feature Importance")
plt.title("Gradient Boosting: Feature Importances")
plt.tight_layout()
plt.show()

# %%
import shap

# Instantiate a SHAP explorer with your model
explainer = shap.Explainer(gb_model)

# Calculate SHAP values ​​for your training data
shap_values = explainer.shap_values(X_train)

# Calculate SHAP values ​​for all training data
shap_values = explainer.shap_values(X_train)

# features importances
shap.summary_plot(shap_values, X_train, plot_type="bar")

# View feature explanations for all workout data
shap.summary_plot(shap_values, X_train, feature_names=X_train.columns)

# dependency diagram
for features in X_train.columns[:-89]:
    shap.dependence_plot(features, shap_values, X_train)

# %%
#Gradient Boosting Regressor scores

print('The score for the train set in Gradient Boosting Regressor model is', gb_model.score(X_train, y_train))
print('The score for the test set in Gradient Boosting Regressor model is',gb_model.score(X_test, y_test))

gb_mae = mean_absolute_error(y_test, gb_predictions)
gb_mse = mean_squared_error(y_test, gb_predictions)
gb_r2 = r2_score(y_test, gb_predictions)

print("Gradient Boosting: MAE =", gb_mae, "MSE =", gb_mse, "R2 =", gb_r2)
# Out:
# The score for the train set in Gradient Boosting Regressor model is 0.6685436798838547
# The score for the test set in Gradient Boosting Regressor model is 0.47795422494520334
# Gradient Boosting: MAE = 0.36886456051619426 MSE = 0.20860579578025282 R2 = 0.47795422494520334

# %%
# Model 2: Linear Regression
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
lr_predictions = lr_model.predict(X_test)
import matplotlib.pyplot as plt

#scatter plot compares the actual target values (y_test) with the predicted values (lr_predictions). It give you a visual sense of how closely the predictions align with the true values.
plt.scatter(y_test, lr_predictions)
plt.xlabel("Actual Surface Temperature Anomaly")
plt.ylabel("Predicted Surface Temperature Anomaly")
plt.title("Linear Regression: Actual vs. Predicted")
plt.show()

#residual plot shows the difference between the actual target values and the predicted values
residuals = y_test - lr_predictions
plt.hist(residuals, bins=30)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Linear Regression: Histogram of Residuals")
plt.show()

#coefficient regression
coef_df = pd.DataFrame({'feature': X_encoded.columns, 'coefficient': lr_model.coef_})
plt.figure(figsize=(18, 6))
plt.bar(coef_df['feature'], coef_df['coefficient'])
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("Coefficient Value")
plt.title("Linear Regression: Coefficients")
plt.show()

# %%
#Linear Regression model scores

print('The score for the train set in Linear Regression model is', lr_model.score(X_train, y_train))
print('The score for the test set in Linear Regression model is',lr_model.score(X_test, y_test))
lr_mae = mean_absolute_error(y_test, lr_predictions)
lr_mse = mean_squared_error(y_test, lr_predictions)
lr_r2 = r2_score(y_test, lr_predictions)

print("Linear Regression: MAE =", lr_mae, "MSE =", lr_mse, "R2 =", lr_r2)
# Out:
# The score for the train set in Linear Regression model is 0.3830772042758873
# The score for the test set in Linear Regression model is 0.2966630838026795
# Linear Regression: MAE = 0.42701363077605214 MSE = 0.2810484522924652 R2 = 0.2966630838026795

# %%
#Model 3, Decision Tree Regressor, Natalia

from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=42)
regressor.fit(X_train, y_train)
y_pred = regressor.predict(X_test)

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("True value (y_test)")
plt.ylabel("Prediction (y_pred)")
plt.title("Check for Overfitting/Underfitting in Decision Tree Regressor model")
plt.show()

#residual plot shows the difference between the actual target values and the predicted values
residuals = y_test - y_pred
plt.hist(residuals, bins=30)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Decision Tree Regressor: Histogram of Residuals")
plt.show()

feature_importance = regressor.feature_importances_
plt.figure(figsize=(18, 6))
plt.bar(X_encoded.columns[:15], feature_importance[:15])
plt.xlabel("Features")
plt.ylabel("Importance")
plt.title("Features Importance Decision Tree Regressor")
plt.xticks(rotation=90)
plt.show()

# %%
# Instantiate a SHAP explorer with  model
explainer = shap.Explainer(regressor)

# Calculate SHAP values ​​for  training data
shap_values = explainer.shap_values(X_train)

# Calculate SHAP values ​​for all training data
shap_values = explainer.shap_values(X_train)

# features importances
shap.summary_plot(shap_values, X_train, plot_type="bar")

# View feature explanations for all workout data
shap.summary_plot(shap_values, X_train, feature_names=X_train.columns)

# dependency diagram
for features in X_train.columns[:-89]:
    shap.dependence_plot(features, shap_values, X_train)

# %%
print('The score for the train set in Decision Tree Regressor model is', regressor.score(X_train, y_train))
print('The score for the test set in Decision Tree Regressor model is',regressor.score(X_test, y_test))

rmse_dtr = mean_squared_error(y_test, y_pred, squared=False)
regressor_mae = mean_absolute_error(y_test, y_pred)
regressor_mse = mean_squared_error(y_test, y_pred)
regressor_r2 = r2_score(y_test, y_pred)

print("Decision Tree Regressor: MAE =", regressor_mae, "MSE =", regressor_mse, "R2 =", regressor_r2)
print('The mean squared error for Decision Tree Regressor model is', rmse_dtr)
# Out:
# The score for the train set in Decision Tree Regressor model is 1.0
# The score for the test set in Decision Tree Regressor model is 0.1449729358152837
# Decision Tree Regressor: MAE = 0.4771548117154812 MSE = 0.3416627615062761 R2 = 0.1449729358152837
# The mean squared error for Decision Tree Regressor model is 0.5845192567454696

# %%
#Model 4, Random Forest Regressor, Natalia

from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
y_pred_rfr = model.predict(X_test)

# %%
plt.scatter(y_test, y_pred_rfr)
plt.xlabel("True value (y_test)")
plt.ylabel("Prediction (y_pred)")
plt.title("Check for Overfitting/Underfitting in Random Forest Regressor model")
plt.show()

#residual plot shows the difference between the actual target values and the predicted values
residuals = y_test - y_pred_rfr
plt.hist(residuals, bins=30)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Random Forest Regressor: Histogram of Residuals")
plt.show()

feature_importance = model.feature_importances_
plt.figure(figsize=(18, 6))
plt.bar(X_encoded.columns[:15], feature_importance[:15])
plt.xlabel("Features")
plt.ylabel("Importance")
plt.title("Features Importance Random Forest Regressor")
plt.xticks(rotation=90)
plt.show()

# %%
# Instantiate a SHAP explorer with  model
explainer = shap.Explainer(model)

# Calculate SHAP values ​​for  training data
shap_values = explainer.shap_values(X_train)

# Calculate SHAP values ​​for all training data
shap_values = explainer.shap_values(X_train)

# features importances
shap.summary_plot(shap_values, X_train, plot_type="bar")

# View feature explanations for all workout data
shap.summary_plot(shap_values, X_train, feature_names=X_train.columns)

# dependency diagram
for features in X_train.columns[:-89]:
    shap.dependence_plot(features, shap_values, X_train)

# %%
print('The score for the train set in Random Forest Regressor model is', model.score(X_train, y_train))
print('The score for the test set in Random Forest Regressor model is', model.score(X_test, y_test))


rmse_rfr = mean_squared_error(y_test, y_pred_rfr, squared=False)
rfr_mae = mean_absolute_error(y_test, y_pred_rfr)
rfr_mse = mean_squared_error(y_test, y_pred_rfr)
rfr_r2 = r2_score(y_test, y_pred_rfr)

print("Random Forest Regressor: MAE =", rfr_mae, "MSE =", rfr_mse, "R2 =", rfr_r2)
print('The mean squared error for Random Forest Regressor model is', rmse_rfr)
# Out:
# The score for the train set in Random Forest Regressor model is 0.9192371003443776
# The score for the test set in Random Forest Regressor model is 0.45153963992793
# Decision Tree Regressor: MAE = 0.3865979079497908 MSE = 0.21916087694560674 R2 = 0.45153963992793
# The mean squared error for Decision Tree Regressor model is 0.46814621321293065

# %% [markdown]
# # Nowa sekcja
